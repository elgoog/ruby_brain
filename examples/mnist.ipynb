# %% [markdown]
# require mnist relevant module. It helps you use mnist dataset.

# %%
require 'nyaplot'
require 'ruby_brain'
require 'ruby_brain/dataset/mnist/data'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# true

# %% [markdown]
# First, add argmax function into Array class.
# This method finds the index of the array position the max value exists and helpful for following steps

# %%
class Array
  def argmax
    max_i, max_val = 0, self.first
    self.each_with_index do |v, i|
      max_val, max_i = v, i if v > max_val
    end
    max_i
  end
end
# Out:
# :argmax

# %% [markdown]
# Get MNIST dataset from [THE MNIST DATABASE of handwritten digits](http://yann.lecun.com/exdb/mnist/) if the dataset files don't exist in the working directory. And load them into Ruby dictionary `dataset`

# %%
dataset = RubyBrain::DataSet::Mnist::data
training_dataset = dataset.first
test_dataset = dataset.last

# dataset has :input and :output dataset
training_dataset.keys # => [:input, :output]
test_dataset.keys # => [:input, :output]

# :input of training_dataset has 60000(samples) x 784(28 * 28 input pixcels)
training_dataset[:input].size       # => 60000
training_dataset[:input].first.size # => 784

# :output of training_dataset has 60000(samples) x 10(classes 0~9)
training_dataset[:output].size       # => 60000
training_dataset[:output].first.size # => 10

# :input of test_dataset has 10000(samples) x 784(28 * 28 input pixcels)
test_dataset[:input].size       # => 10000
test_dataset[:input].first.size # => 784

# :output of test_dataset has 10000(samples) x 10(classes 0~9)
test_dataset[:output].size       # => 10000
test_dataset[:output].first.size # => 10
# Out:
# 10

# %% [markdown]
# In this example, We use only first 5000 samples of training_dataset
# because RubyBrain is slow and it takes very long time to learn full training_dataset.
# `NUM_TRAIN_DATA` means how many first images are used as training data.
# Here it is set as 5000.

# %%
# use only first 5000 samples for training
NUM_TRAIN_DATA = 5000
training_input = training_dataset[:input][0..(NUM_TRAIN_DATA-1)]
training_supervisor = training_dataset[:output][0..(NUM_TRAIN_DATA-1)]
# use full test dataset
test_input = test_dataset[:input]
test_supervisor = test_dataset[:output]
nil

# %% [markdown]
# You can see some `training_input` and `training_supervisor` with following code

# %%
5.times do |s|
  x = []
  y = []
  z = []
  28.times do |i|
    28.times do |j|
      x.push(j)
      y.push(-i)
      z.push(training_input[s][i*28+j])
    end
  end
  puts "training_input[#{s}] : "
  plot1 = Nyaplot::Plot.new
  mnistm = plot1.add(:heatmap, x, y, z)
  mnistm.stroke_width("0")
  mnistm.height(1.0)
  mnistm.width(1.0)
  plot1.legend(true)
  plot1.show
  puts "training_supervisor[#{s}] : #{training_supervisor[s].argmax}\n"
  puts "-------------------------------------------------------------------------------------\n"
end
# Out:
# training_input[0] :
# #<Nyaplot::Frame:0x005650ee4ca898 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee495468 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee4cb158 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"62a736a5-189c-4f7b-84c8-c3a270a0bbf9"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"62a736a5-189c-4f7b-84c8-c3a270a0bbf9"=>#<Nyaplot::DataFrame:0x005650ee494e00 @name="62a736a5-189c-4f7b-84c8-c3a270a0bbf9", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# training_supervisor[0] : 5
#
# -------------------------------------------------------------------------------------
#
# training_input[1] :
# #<Nyaplot::Frame:0x005650ee65a118 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee54f8b8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee65a898 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"493ccab6-1464-42a3-9d1e-b01f07a6f7e4"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"493ccab6-1464-42a3-9d1e-b01f07a6f7e4"=>#<Nyaplot::DataFrame:0x005650ee54f2f0 @name="493ccab6-1464-42a3-9d1e-b01f07a6f7e4", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# training_supervisor[1] : 0
#
# -------------------------------------------------------------------------------------
#
# training_input[2] :
# #<Nyaplot::Frame:0x005650ee7e4ce0 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee6db538 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee7e5460 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"2a1ec705-b30d-443d-bfce-ea8fc9cc7a68"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"2a1ec705-b30d-443d-bfce-ea8fc9cc7a68"=>#<Nyaplot::DataFrame:0x005650ee6daf70 @name="2a1ec705-b30d-443d-bfce-ea8fc9cc7a68", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# training_supervisor[2] : 4
#
# -------------------------------------------------------------------------------------
#
# training_input[3] :
# #<Nyaplot::Frame:0x005650ee962090 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee934cf8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee962810 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"34a1f461-e0e1-4324-b857-7b49f5be05b1"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"34a1f461-e0e1-4324-b857-7b49f5be05b1"=>#<Nyaplot::DataFrame:0x005650ee934730 @name="34a1f461-e0e1-4324-b857-7b49f5be05b1", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# training_supervisor[3] : 1
#
# -------------------------------------------------------------------------------------
#
# training_input[4] :
# #<Nyaplot::Frame:0x005650eeace9b0 @properties={:panes=>[#<Nyaplot::Plot:0x005650eea95840 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eeacf130 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"b9b2452d-c707-4b38-8299-0f8afaa59c39"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"b9b2452d-c707-4b38-8299-0f8afaa59c39"=>#<Nyaplot::DataFrame:0x005650eea95278 @name="b9b2452d-c707-4b38-8299-0f8afaa59c39", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# training_supervisor[4] : 9
#
# -------------------------------------------------------------------------------------
# 5

# %% [markdown]
# Then construct the network and initialize.
# In this case, an image has 784(28x28) pixcels and 10 classes(0..9).
# So, the network structure should be `[784, 50, 10]` with 1 hidden layer which has 50 units.
# You can construct the structure with following code.

# %%
# network structure [784, 50, 10]
network = RubyBrain::Network.new([training_input.first.size, 50, training_supervisor.first.size])
# learning rate is 0.7
network.learning_rate = 0.7
# initialize network
network.init_network

# %% [markdown]
# Run training

# %%
org_stdout = $stdout
$stdout = File.open(File::NULL, "w")
network.learn(training_input, training_supervisor, max_training_count=100, tolerance=0.0004, monitoring_channels=[:best_params_training])
$stdout = org_stdout
# Out:
# #<IRuby::OStream:0x005650cabe9620 @session=#<IRuby::Session:0x005650cabea5c0 @sockets={:publish=>#<ZMQ::Socket::Pub:0x005650cabea160>, :reply=>#<ZMQ::Socket::Router:0x005650cabea390>, :stdin=>#<ZMQ::Socket::Router:0x005650cabe9fd0>}, @session="212cd2dd-89a1-4b65-8b62-f948ffaf7920", @hmac=c8c2f7df1301a9acb8b6525521d8b7d2dc895622a8fea3776aa3c8ab12a1a171, @last_recvd_msg={:idents=>["A27A3F615B364779AE90CA4F32C28EFA"], :header=>{"version"=>"5.0", "msg_id"=>"3F707483601B4A35AF6F9DE453F23281", "session"=>"A27A3F615B364779AE90CA4F32C28EFA", "username"=>"username", "msg_type"=>"execute_request"}, :parent_header=>{}, :metadata=>{}, :content=>{"user_expressions"=>{}, "code"=>"org_stdout = $stdout\n$stdout = File.open(File::NULL, \"w\")\nnetwork.learn(training_input, training_supervisor, max_training_count=100, tolerance=0.0004, monitoring_channels=[:best_params_training])\n$stdout = org_stdout", "allow_stdin"=>true, "silent"=>false, "stop_on_error"=>true, "store_history"=>true}, :buffers=>nil}>, @name=:stdout>

# %% [markdown]
# Now, An optimized network was completed.
# You can check it.

# %% [markdown]
# You can get the accuracy with following code

# %%
results = []
test_input.each_with_index do |input, i|
  supervisor_label = test_supervisor[i].argmax
  predicated_label = network.get_forward_outputs(input).argmax
  results << (supervisor_label == predicated_label)
end

puts "accuracy: #{results.count(true).to_f/results.size}"
# Out:
# accuracy: 0.9271

# %% [markdown]
# Review actual images and predicated classes

# %%
test_input[0..20].each_with_index do |input, s|
  x = []
  y = []
  z = []
  28.times do |i|
    28.times do |j|
      x.push(j)
      y.push(-i)
      z.push(test_input[s][i*28+j])
    end
  end
  puts "test_input[#{s}] : "
  plot1 = Nyaplot::Plot.new
  mnistm = plot1.add(:heatmap, x, y, z)
  mnistm.stroke_width("0")
  mnistm.height(1.0)
  mnistm.width(1.0)
  plot1.legend(true)
  plot1.show
  puts "test_supervisor[#{s}] : #{test_supervisor[s].argmax}\n"
  puts "predicated_class : #{network.get_forward_outputs(input).argmax}"
  puts "-------------------------------------------------------------------------------------\n"
end
nil
# Out:
# test_input[0] :
# #<Nyaplot::Frame:0x005650eea94d78 @properties={:panes=>[#<Nyaplot::Plot:0x005650eec32fb8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eea95570 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"6813a403-e2ea-48b5-84c9-c42c8e432060"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"6813a403-e2ea-48b5-84c9-c42c8e432060"=>#<Nyaplot::DataFrame:0x005650eec329a0 @name="6813a403-e2ea-48b5-84c9-c42c8e432060", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[0] : 7
#
# predicated_class : 7
# -------------------------------------------------------------------------------------
#
# test_input[1] :
# #<Nyaplot::Frame:0x005650caa32c28 @properties={:panes=>[#<Nyaplot::Plot:0x005650cab89c48 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650caa33c68 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"7b0f6112-ba2b-4cad-8fc9-d23650394d15"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"7b0f6112-ba2b-4cad-8fc9-d23650394d15"=>#<Nyaplot::DataFrame:0x005650cab88ac8 @name="7b0f6112-ba2b-4cad-8fc9-d23650394d15", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[1] : 2
#
# predicated_class : 2
# -------------------------------------------------------------------------------------
#
# test_input[2] :
# #<Nyaplot::Frame:0x005650ef03a840 @properties={:panes=>[#<Nyaplot::Plot:0x005650eedc2888 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ef03afc0 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"087cd775-6536-4b53-86c9-7dd61384faa1"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"087cd775-6536-4b53-86c9-7dd61384faa1"=>#<Nyaplot::DataFrame:0x005650eedc2248 @name="087cd775-6536-4b53-86c9-7dd61384faa1", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[2] : 1
#
# predicated_class : 1
# -------------------------------------------------------------------------------------
#
# test_input[3] :
# #<Nyaplot::Frame:0x005650ee96ba50 @properties={:panes=>[#<Nyaplot::Plot:0x005650eefe7c80 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eefb0258 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"b4d6d0fe-73ac-4c91-9c20-9f6579c6925d"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"b4d6d0fe-73ac-4c91-9c20-9f6579c6925d"=>#<Nyaplot::DataFrame:0x005650eefe76b8 @name="b4d6d0fe-73ac-4c91-9c20-9f6579c6925d", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[3] : 0
#
# predicated_class : 0
# -------------------------------------------------------------------------------------
#
# test_input[4] :
# #<Nyaplot::Frame:0x005650cb4ebd90 @properties={:panes=>[#<Nyaplot::Plot:0x005650cb59ae80 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650cb4f0b88 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"dc54ec3c-034a-43d1-ba0a-053a504a49d4"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"dc54ec3c-034a-43d1-ba0a-053a504a49d4"=>#<Nyaplot::DataFrame:0x005650cb59a890 @name="dc54ec3c-034a-43d1-ba0a-053a504a49d4", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[4] : 4
#
# predicated_class : 4
# -------------------------------------------------------------------------------------
#
# test_input[5] :
# #<Nyaplot::Frame:0x005650eed90d10 @properties={:panes=>[#<Nyaplot::Plot:0x005650eef10c80 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eed914e0 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"b69cefe6-d03f-456e-8761-6ee764c006b6"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"b69cefe6-d03f-456e-8761-6ee764c006b6"=>#<Nyaplot::DataFrame:0x005650eef106b8 @name="b69cefe6-d03f-456e-8761-6ee764c006b6", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[5] : 1
#
# predicated_class : 1
# -------------------------------------------------------------------------------------
#
# test_input[6] :
# #<Nyaplot::Frame:0x005650eeffb258 @properties={:panes=>[#<Nyaplot::Plot:0x005650eef89220 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eeffba00 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"3e2fab95-078c-40ce-b7ec-e55071bd1f29"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"3e2fab95-078c-40ce-b7ec-e55071bd1f29"=>#<Nyaplot::DataFrame:0x005650eef88c30 @name="3e2fab95-078c-40ce-b7ec-e55071bd1f29", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[6] : 4
#
# predicated_class : 4
# -------------------------------------------------------------------------------------
#
# test_input[7] :
# #<Nyaplot::Frame:0x005650cc28a9b0 @properties={:panes=>[#<Nyaplot::Plot:0x005650cc803338 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650cc28b180 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"9bb30fbb-0e95-49c6-bb74-63b4a5d280c1"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"9bb30fbb-0e95-49c6-bb74-63b4a5d280c1"=>#<Nyaplot::DataFrame:0x005650cc802d20 @name="9bb30fbb-0e95-49c6-bb74-63b4a5d280c1", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[7] : 9
#
# predicated_class : 9
# -------------------------------------------------------------------------------------
#
# test_input[8] :
# #<Nyaplot::Frame:0x005650ee995698 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee4ed4b0 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee995e40 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"25367702-4b66-46b1-836e-1bdafe9e9f94"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"25367702-4b66-46b1-836e-1bdafe9e9f94"=>#<Nyaplot::DataFrame:0x005650ee4ecee8 @name="25367702-4b66-46b1-836e-1bdafe9e9f94", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[8] : 5
#
# predicated_class : 2
# -------------------------------------------------------------------------------------
#
# test_input[9] :
# #<Nyaplot::Frame:0x005650eeca9988 @properties={:panes=>[#<Nyaplot::Plot:0x005650eed996b8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eecaa108 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"e477cba5-7678-44fd-a61a-d44ab2d7930b"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"e477cba5-7678-44fd-a61a-d44ab2d7930b"=>#<Nyaplot::DataFrame:0x005650eed990f0 @name="e477cba5-7678-44fd-a61a-d44ab2d7930b", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[9] : 9
#
# predicated_class : 9
# -------------------------------------------------------------------------------------
#
# test_input[10] :
# #<Nyaplot::Frame:0x005650ee4a9378 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee6422e8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee4a9c88 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"b3147d06-4f4b-4799-9f6a-ce44ca90fbd8"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"b3147d06-4f4b-4799-9f6a-ce44ca90fbd8"=>#<Nyaplot::DataFrame:0x005650ee641c08 @name="b3147d06-4f4b-4799-9f6a-ce44ca90fbd8", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[10] : 0
#
# predicated_class : 0
# -------------------------------------------------------------------------------------
#
# test_input[11] :
# ...
# test_supervisor[17] : 7
#
# predicated_class : 7
# -------------------------------------------------------------------------------------
#
# test_input[18] :
# #<Nyaplot::Frame:0x005650eee4fdf0 @properties={:panes=>[#<Nyaplot::Plot:0x005650eed303c0 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650ee540778 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"eabbc736-260a-4cdc-a5ab-ca01ad210623"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"eabbc736-260a-4cdc-a5ab-ca01ad210623"=>#<Nyaplot::DataFrame:0x005650eeda7d80 @name="eabbc736-260a-4cdc-a5ab-ca01ad210623", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[18] : 3
#
# predicated_class : 3
# -------------------------------------------------------------------------------------
#
# test_input[19] :
# #<Nyaplot::Frame:0x005650eed29fc0 @properties={:panes=>[#<Nyaplot::Plot:0x005650ee7f7228 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650eed2a948 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"46f25dc5-7777-4de6-874d-985707374137"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"46f25dc5-7777-4de6-874d-985707374137"=>#<Nyaplot::DataFrame:0x005650ee7f6c60 @name="46f25dc5-7777-4de6-874d-985707374137", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[19] : 4
#
# predicated_class : 4
# -------------------------------------------------------------------------------------
#
# test_input[20] :
# #<Nyaplot::Frame:0x005650cb442ec0 @properties={:panes=>[#<Nyaplot::Plot:0x005650cb56a708 @properties={:diagrams=>[#<Nyaplot::Diagram:0x005650cb443870 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_width=>"0", :height=>1.0, :width=>1.0}, :data=>"ccce2199-7f87-4e16-a50b-577daa826f33"}, @xrange=[0, 27], @yrange=[-27, 0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 27], :yrange=>[-27, 0]}}>], :data=>{"ccce2199-7f87-4e16-a50b-577daa826f33"=>#<Nyaplot::DataFrame:0x005650cb569fb0 @name="ccce2199-7f87-4e16-a50b-577daa826f33", @rows=[{:data0=>0, :data1=>0, :data2=>0.0}, {:data0=>1, :data1=>0, :data2=>0.0}, {:data0=>2, :data1=>0, :data2=>0.0}, {:data0=>3, :data1=>0, :data2=>0.0}, {:data0=>4, :data1=>0, :data2=>0.0}, {:data0=>5, :data1=>0, :data2=>0.0}, {:data0=>6, :data1=>0, :data2=>0.0}, {:data0=>7, :data1=>0, :data2=>0.0}, {:data0=>8, :data1=>0, :data2=>0.0}, {:data0=>9, :data1=>0, :data2=>0.0}, {:data0=>10, :data1=>0, :data2=>0.0}, {:data0=>11, :data1=>0, :data2=>0.0}, {:data0=>12, :data1=>0, :data2=>0.0}, {:data0=>13, :data1=>0, :data2=>0.0}, {:data0=>14, :data1=>0, :data2=>0.0}, {:data0=>15, :data1=>0, :data2=>0.0}, {:data0=>16, :data1=>0, :data2=>0.0}, {:data0=>17, :data1=>0, :data2=>0.0}, {:data0=>18, :data1=>0, :data2=>0.0}, {:data0=>19, :data1=>0, :data2=>0.0}, {:data0=>20, :data1=>0, :data2=>0.0}, {:data0=>21, :data1=>0, :data2=>0.0}, {:data0=>22, :data1=>0, :data2=>0.0}, {:data0=>23, :data1=>0, :data2=>0.0}, {:data0=>24, :data1=>0, :data2=>0.0}, {:data0=>25, :data1=>0, :data2=>0.0}, {:data0=>26, :data1=>0, :data2=>0.0}, {:data0=>27, :data1=>0, :data2=>0.0}, {:data0=>0, :data1=>-1, :data2=>0.0}, {:data0=>1, :data1=>-1, :data2=>0.0}, {:data0=>2, :data1=>-1, :data2=>0.0}, {:data0=>3, :data1=>-1, :data2=>0.0}, {:data0=>4, :data1=>-1, :data2=>0.0}, {:data0=>5, :data1=>-1, :data2=>0.0}, {:data0=>6, :data1=>-1, :data2=>0.0}, {:data0=>7, :data1=>-1, :data2=>0.0}, {:data0=>8, :data1=>-1, :data2=>0.0}, {:data0=>9, :data1=>-1, :data2=>0.0}, {:data0=>10, :data1=>-1, :data2=>0.0}, {:data0=>11, :data1=>-1, :data2=>0.0}, {:data0=>12, :data1=>-1, :data2=>0.0}, {:data0=>13, :data1=>-1, :data2=>0.0}, {:data0=>14, :data1=>-1, :data2=>0.0}, {:data0=>15, :data1=>-1, :data2=>0.0}, {:data0=>16, :data1=>-1, :data2=>0.0}, {:data0=>17, :data1=>-1, :data2=>0.0}, {:data0=>18, :data1=>-1, :data2=>0.0}, {:data0=>19, :data1=>-1, :data2=>0.0}, {:data0=>20, :data1=>-1, :data2=>0.0}, {:data0=>21, :data1=>-1, :data2=>0.0}, {:data0=>22, :data1=>-1, :data2=>0.0}, {:data0=>23, :data1=>-1, :data2=>0.0}, {:data0=>24, :data1=>-1, :data2=>0.0}, {:data0=>25, :data1=>-1, :data2=>0.0}, {:data0=>26, :data1=>-1, :data2=>0.0}, {:data0=>27, :data1=>-1, :data2=>0.0}, {:data0=>0, :data1=>-2, :data2=>0.0}, {:data0=>1, :data1=>-2, :data2=>0.0}, {:data0=>2, :data1=>-2, :data2=>0.0}, {:data0=>3, :data1=>-2, :data2=>0.0}, {:data0=>4, :data1=>-2, :data2=>0.0}, {:data0=>5, :data1=>-2, :data2=>0.0}, {:data0=>6, :data1=>-2, :data2=>0.0}, {:data0=>7, :data1=>-2, :data2=>0.0}, {:data0=>8, :data1=>-2, :data2=>0.0}, {:data0=>9, :data1=>-2, :data2=>0.0}, {:data0=>10, :data1=>-2, :data2=>0.0}, {:data0=>11, :data1=>-2, :data2=>0.0}, {:data0=>12, :data1=>-2, :data2=>0.0}, {:data0=>13, :data1=>-2, :data2=>0.0}, {:data0=>14, :data1=>-2, :data2=>0.0}, {:data0=>15, :data1=>-2, :data2=>0.0}, {:data0=>16, :data1=>-2, :data2=>0.0}, {:data0=>17, :data1=>-2, :data2=>0.0}, {:data0=>18, :data1=>-2, :data2=>0.0}, {:data0=>19, :data1=>-2, :data2=>0.0}, {:data0=>20, :data1=>-2, :data2=>0.0}, {:data0=>21, :data1=>-2, :data2=>0.0}, {:data0=>22, :data1=>-2, :data2=>0.0}, {:data0=>23, :data1=>-2, :data2=>0.0}, {:data0=>24, :data1=>-2, :data2=>0.0}, {:data0=>25, :data1=>-2, :data2=>0.0}, {:data0=>26, :data1=>-2, :data2=>0.0}, {:data0=>27, :data1=>-2, :data2=>0.0}, {:data0=>0, :data1=>-3, :data2=>0.0}, {:data0=>1, :data1=>-3, :data2=>0.0}, {:data0=>2, :data1=>-3, :data2=>0.0}, {:data0=>3, :data1=>-3, :data2=>0.0}, {:data0=>4, :data1=>-3, :data2=> ...
# test_supervisor[20] : 9
#
# predicated_class : 9
# -------------------------------------------------------------------------------------
